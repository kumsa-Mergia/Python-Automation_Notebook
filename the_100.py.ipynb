# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd

# %%
hundred = pd.read_html('https://en.wikipedia.org/wiki/List_of_The_100_episodes')

# %%
len(hundred)
# Out:
# 26

# %%
hundred[1]
# Out:
#                                           No. overall  \
# 0                                                   1
# 1   Set in an indeterminate year in the future, 97...
# 2                                                   2
# 3   Chancellor Jaha recovers and learns of his son...
# 4                                                   3
# 5   In flashbacks, Clarke's engineer father Jake d...
# 6                                                   4
# 7   Monty attempts to use the wristbands to contac...
# 8                                                   5
# 9   Raven, unconscious, has made it to the ground....
# 10                                                  6
# 11  This episode's plot summary may be too long or...
# 12                                                NaN
# 13                                                  7
# 14  In the midst of a hurricane on the ground, Fin...
# 15                                                  8
# ...
